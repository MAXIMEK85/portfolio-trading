# %% [markdown]
# <a href="https://colab.research.google.com/github/MAXIMEK85/portfolio-trading/blob/main/Quant1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
import pandas as pd

equities = ["MC.PA","MMM","PYPL","NKE","BABA","JD"]
period = 14
for ticket in equities:

  df= yf.download(ticket, start="2020-01-01")
  print(df.columns)
  close = df[("Close",ticket)] if isinstance(df.columns, pd.MultiIndex) else df["Close"]
  close = close.dropna()

  #RSI
  delta = close.diff()
  gain = delta.clip(lower=0)
  loss = -delta.clip(upper=0)
  avg_gain = gain.ewm(alpha=1/period,adjust=False).mean()
  avg_loss = loss.ewm(alpha=1/period,adjust=False).mean()
  rs = (avg_gain / avg_loss)
  rsi = 100 - (100 / (1+ rs))

  SMA = df["Close"].rolling(window=200).mean()

  peaks,_=find_peaks(close)

  plt.plot(rsi, label="RSI")
  plt.title(ticket)
  plt.xlabel("time")
  plt.ylabel("%")
  plt.axhline(50, color="black", label="Mediane")
  plt.axhline(25, color="purple", label="25%")
  plt.axhline(75, color="yellow", label="75%")
  plt.legend()
  plt.figure()
  plt.plot(SMA,label ="SMA")
  plt.plot(close.index, close, label="Close Price")
  plt.plot(close.index[peaks], close.iloc[peaks], "yo", label="Peaks")

  plt.title(ticket)
  plt.xlabel("time")
  plt.ylabel("price")
  plt.legend()
  plt.figure()

  plt.hist(df["Volume"], bins=200)
  plt.title("Volume")
  plt.xlabel("nombre de jours")
  plt.ylabel("Taille du volume")
  plt.show()


  print(df["Volume"].describe())

  high_volume = df[df["Volume"] > df["Volume"].mean()]
  print(high_volume["Close"])

  t = df["Volume"].pct_change()
  print(t)

  buy = rsi[rsi <25]
  for date, value in buy.items():
    print(f"{ticket}BUY on {date.date()}")

  sell = rsi[rsi >75]
  for date, value in sell.items():
    print(f"{ticket}BUY on {date.date()}-RSI = {value:.1f}")
# Out:
# /tmp/ipython-input-839104772.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df= yf.download(ticket, start="2020-01-01")
# [*********************100%***********************]  1 of 1 completed
# MultiIndex([( 'Close', 'MC.PA'),
#             (  'High', 'MC.PA'),
#             (   'Low', 'MC.PA'),
#             (  'Open', 'MC.PA'),
#             ('Volume', 'MC.PA')],
#            names=['Price', 'Ticker'])
# Ticker         MC.PA
# count   1.521000e+03
# mean    4.568468e+05
# std     2.699072e+05
# min     4.839200e+04
# 25%     3.070870e+05
# 50%     3.863270e+05
# 75%     5.170190e+05
# max     3.098476e+06
# Ticker      MC.PA
# Date
# 2020-01-02    NaN
# 2020-01-03    NaN
# 2020-01-06    NaN
# 2020-01-07    NaN
# 2020-01-08    NaN
# ...           ...
# 2025-11-28    NaN
# 2025-12-01    NaN
# 2025-12-02    NaN
# 2025-12-03    NaN
# 2025-12-04    NaN
#
# [1521 rows x 1 columns]
# Ticker         MC.PA
# Date
# 2020-01-02       NaN
# 2020-01-03 -0.159867
# 2020-01-06  0.247628
# 2020-01-07 -0.000187
# 2020-01-08 -0.008640
# ...              ...
# 2025-11-28  1.413350
# 2025-12-01 -0.032027
# 2025-12-02  0.004987
# 2025-12-03 -0.122288
# 2025-12-04  0.178275
#
# [1521 rows x 1 columns]
# MC.PABUY on 2020-01-03
# MC.PABUY on 2020-01-06
# MC.PABUY on 2020-01-07
# MC.PABUY on 2020-03-10
# MC.PABUY on 2020-03-11
# MC.PABUY on 2020-03-12
# MC.PABUY on 2020-03-16
# MC.PABUY on 2024-01-17
# MC.PABUY on 2025-03-24
# MC.PABUY on 2025-03-27
# MC.PABUY on 2025-03-28
# MC.PABUY on 2025-03-31
# MC.PABUY on 2025-04-01
# MC.PABUY on 2025-04-02
# MC.PABUY on 2025-04-03
# MC.PABUY on 2025-04-04
# MC.PABUY on 2025-04-07
# MC.PABUY on 2025-04-08
# MC.PABUY on 2025-04-09
# MC.PABUY on 2025-04-16
# MC.PABUY on 2025-04-17
# MC.PABUY on 2020-01-14-RSI = 79.6
# MC.PABUY on 2020-01-15-RSI = 80.1
# MC.PABUY on 2020-01-16-RSI = 80.7
# MC.PABUY on 2020-01-17-RSI = 86.8
# MC.PABUY on 2020-11-10-RSI = 75.3
# MC.PABUY on 2020-11-11-RSI = 78.2
# MC.PABUY on 2021-04-14-RSI = 79.8
# MC.PABUY on 2021-04-15-RSI = 81.1
# MC.PABUY on 2021-04-16-RSI = 84.0
# MC.PABUY on 2021-04-19-RSI = 79.0
# MC.PABUY on 2021-06-17-RSI = 75.2
# MC.PABUY on 2022-07-29-RSI = 75.3
# MC.PABUY on 2022-08-01-RSI = 77.8
# MC.PABUY on 2022-08-04-RSI = 75.2
# MC.PABUY on 2022-11-30-RSI = 75.0
# MC.PABUY on 2023-01-18-RSI = 75.5
# MC.PABUY on 2024-02-08-RSI = 76.0
# MC.PABUY on 2024-02-09-RSI = 76.6
# MC.PABUY on 2024-02-12-RSI = 79.0
# MC.PABUY on 2024-02-22-RSI = 76.1
# MC.PABUY on 2024-02-23-RSI = 77.9
# MC.PABUY on 2025-01-27-RSI = 77.5
# MC.PABUY on 2025-01-28-RSI = 75.4
# /tmp/ipython-input-839104772.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df= yf.download(ticket, start="2020-01-01")
# [*********************100%***********************]  1 of 1 completed
# MultiIndex([( 'Close', 'MMM'),
#             (  'High', 'MMM'),
#             (   'Low', 'MMM'),
#             (  'Open', 'MMM'),
#             ('Volume', 'MMM')],
#            names=['Price', 'Ticker'])
# Ticker           MMM
# count   1.490000e+03
# mean    4.186429e+06
# std     4.089107e+06
# min     7.848150e+05
# 25%     2.621925e+06
# 50%     3.287565e+06
# 75%     4.404001e+06
# max     6.043675e+07
# Ticker             MMM
# Date
# 2020-01-02  120.682503
# 2020-01-03         NaN
# 2020-01-06         NaN
# 2020-01-07         NaN
# 2020-01-08         NaN
# ...                ...
# 2025-11-28         NaN
# 2025-12-01         NaN
# 2025-12-02         NaN
# 2025-12-03         NaN
# 2025-12-04         NaN
#
# [1490 rows x 1 columns]
# Ticker           MMM
# Date
# 2020-01-02       NaN
# 2020-01-03 -0.315073
# 2020-01-06 -0.190077
# 2020-01-07  0.087588
# 2020-01-08  0.269351
# ...              ...
# 2025-11-28 -0.214265
# 2025-12-01  0.406127
# 2025-12-02 -0.140827
# 2025-12-03  0.495100
# 2025-12-04 -0.007942
#
# [1490 rows x 1 columns]
# MMMBUY on 2020-01-03
# MMMBUY on 2020-01-06
# MMMBUY on 2020-01-07
# MMMBUY on 2020-01-08
# MMMBUY on 2020-01-09
# MMMBUY on 2020-01-10
# MMMBUY on 2020-01-13
# MMMBUY on 2020-01-14
# MMMBUY on 2020-01-15
# MMMBUY on 2020-01-16
# MMMBUY on 2020-01-21
# MMMBUY on 2020-01-22
# MMMBUY on 2020-01-23
# MMMBUY on 2020-01-24
# MMMBUY on 2020-01-27
# MMMBUY on 2020-01-28
# MMMBUY on 2020-01-29
# MMMBUY on 2020-01-30
# MMMBUY on 2020-01-31
# MMMBUY on 2020-02-03
# MMMBUY on 2020-02-04
# MMMBUY on 2020-02-25
# MMMBUY on 2022-02-17
# MMMBUY on 2022-02-18
# MMMBUY on 2022-02-22
# MMMBUY on 2022-02-23
# MMMBUY on 2022-02-24
# MMMBUY on 2022-06-17
# MMMBUY on 2022-06-21
# MMMBUY on 2022-09-06
# MMMBUY on 2023-10-02
# MMMBUY on 2023-10-03
# MMMBUY on 2023-10-04
# MMMBUY on 2023-10-05
# MMMBUY on 2023-10-06
# MMMBUY on 2024-01-24
# MMMBUY on 2021-04-23-RSI = 75.1
# MMMBUY on 2022-08-12-RSI = 75.9
# MMMBUY on 2023-07-26-RSI = 75.5
# MMMBUY on 2023-12-04-RSI = 79.1
# MMMBUY on 2023-12-14-RSI = 77.7
# MMMBUY on 2023-12-15-RSI = 77.4
# MMMBUY on 2024-03-13-RSI = 77.0
# MMMBUY on 2024-03-15-RSI = 75.7
# MMMBUY on 2024-03-19-RSI = 75.6
# MMMBUY on 2024-03-20-RSI = 79.2
# MMMBUY on 2024-03-21-RSI = 78.2
# MMMBUY on 2024-05-16-RSI = 79.4
# MMMBUY on 2024-05-17-RSI = 79.9
# MMMBUY on 2024-05-20-RSI = 79.7
# MMMBUY on 2024-07-26-RSI = 85.5
# MMMBUY on 2024-07-29-RSI = 80.5
# MMMBUY on 2024-07-30-RSI = 81.5
# MMMBUY on 2024-07-31-RSI = 81.9
# MMMBUY on 2024-08-01-RSI = 79.0
# MMMBUY on 2024-08-02-RSI = 75.8
# MMMBUY on 2024-08-26-RSI = 77.1
# MMMBUY on 2024-08-27-RSI = 75.2
# MMMBUY on 2024-08-28-RSI = 75.5
# MMMBUY on 2024-08-29-RSI = 77.3
# MMMBUY on 2024-08-30-RSI = 79.5
# MMMBUY on 2025-01-21-RSI = 78.1
# MMMBUY on 2025-01-22-RSI = 80.0
# MMMBUY on 2025-01-23-RSI = 80.4
# MMMBUY on 2025-01-24-RSI = 79.7
# MMMBUY on 2025-01-27-RSI = 81.5
# MMMBUY on 2025-01-28-RSI = 81.1
# MMMBUY on 2025-01-29-RSI = 81.2
# MMMBUY on 2025-01-30-RSI = 83.7
# MMMBUY on 2025-01-31-RSI = 75.4
# /tmp/ipython-input-839104772.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df= yf.download(ticket, start="2020-01-01")
# [*********************100%***********************]  1 of 1 completed
# MultiIndex([( 'Close', 'PYPL'),
#             (  'High', 'PYPL'),
#             (   'Low', 'PYPL'),
#             (  'Open', 'PYPL'),
#             ('Volume', 'PYPL')],
#            names=['Price', 'Ticker'])
# Ticker          PYPL
# count   1.490000e+03
# mean    1.264304e+07
# std     8.022340e+06
# min     3.053800e+06
# 25%     7.856225e+06
# 50%     1.090085e+07
# 75%     1.493258e+07
# max     1.362640e+08
# Ticker           PYPL
# Date
# 2020-01-02        NaN
# 2020-01-03        NaN
# 2020-01-06        NaN
# 2020-01-07        NaN
# 2020-01-08        NaN
# ...               ...
# 2025-11-28        NaN
# 2025-12-01        NaN
# 2025-12-02        NaN
# 2025-12-03  61.240002
# 2025-12-04  61.730000
#
# [1490 rows x 1 columns]
# Ticker          PYPL
# Date
# 2020-01-02       NaN
# 2020-01-03 -0.043201
# 2020-01-06 -0.047025
# 2020-01-07  0.019839
# 2020-01-08  0.202198
# ...              ...
# 2025-11-28 -0.055115
# 2025-12-01  0.386927
# 2025-12-02 -0.008166
# 2025-12-03  1.252407
# 2025-12-04 -0.344796
#
# [1490 rows x 1 columns]
# PYPLBUY on 2020-01-03
# PYPLBUY on 2020-01-06
# PYPLBUY on 2020-01-07
# PYPLBUY on 2020-01-08
# PYPLBUY on 2020-01-09
# PYPLBUY on 2020-01-10
# PYPLBUY on 2020-01-13
# PYPLBUY on 2020-01-14
# PYPLBUY on 2020-01-15
# PYPLBUY on 2021-11-09
# PYPLBUY on 2021-11-10
# PYPLBUY on 2021-11-11
# PYPLBUY on 2021-11-22
# PYPLBUY on 2021-11-23
# PYPLBUY on 2021-11-24
# PYPLBUY on 2021-11-26
# PYPLBUY on 2021-11-29
# PYPLBUY on 2021-11-30
# PYPLBUY on 2021-12-01
# PYPLBUY on 2022-02-03
# PYPLBUY on 2022-02-07
# PYPLBUY on 2022-02-08
# PYPLBUY on 2022-02-11
# PYPLBUY on 2022-02-14
# PYPLBUY on 2022-02-16
# PYPLBUY on 2022-02-17
# PYPLBUY on 2022-02-18
# PYPLBUY on 2022-02-22
# PYPLBUY on 2022-02-23
# PYPLBUY on 2022-03-07
# PYPLBUY on 2025-03-04
# PYPLBUY on 2025-04-04
# PYPLBUY on 2025-04-08
# PYPLBUY on 2020-05-07-RSI = 76.9
# PYPLBUY on 2020-05-08-RSI = 75.1
# PYPLBUY on 2020-08-06-RSI = 75.4
# PYPLBUY on 2020-12-22-RSI = 75.8
# PYPLBUY on 2021-02-12-RSI = 77.5
# PYPLBUY on 2021-02-16-RSI = 79.3
# PYPLBUY on 2021-06-24-RSI = 75.0
# /tmp/ipython-input-839104772.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df= yf.download(ticket, start="2020-01-01")
# [*********************100%***********************]  1 of 1 completed
# MultiIndex([( 'Close', 'NKE'),
#             (  'High', 'NKE'),
#             (   'Low', 'NKE'),
#             (  'Open', 'NKE'),
#             ('Volume', 'NKE')],
#            names=['Price', 'Ticker'])
# /tmp/ipython-input-839104772.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df= yf.download(ticket, start="2020-01-01")
# [*********************100%***********************]  1 of 1 completed
# Ticker           NKE
# count   1.490000e+03
# mean    9.362029e+06
# std     7.809599e+06
# min     1.821900e+06
# 25%     5.634925e+06
# 50%     7.428400e+06
# 75%     1.051320e+07
# max     1.299670e+08
# Ticker            NKE
# Date
# 2020-01-02        NaN
# 2020-01-03        NaN
# 2020-01-06        NaN
# 2020-01-07        NaN
# 2020-01-08        NaN
# ...               ...
# 2025-11-28        NaN
# 2025-12-01  65.389999
# 2025-12-02        NaN
# 2025-12-03  65.650002
# 2025-12-04  65.690002
#
# [1490 rows x 1 columns]
# Ticker           NKE
# Date
# 2020-01-02       NaN
# 2020-01-03 -0.195301
# 2020-01-06  0.015544
# 2020-01-07  0.456920
# 2020-01-08 -0.264543
# ...              ...
# 2025-11-28 -0.641694
# 2025-12-01  1.438034
# 2025-12-02 -0.248695
# 2025-12-03  0.328918
# 2025-12-04 -0.117539
#
# [1490 rows x 1 columns]
# NKEBUY on 2020-01-03
# NKEBUY on 2020-01-06
# NKEBUY on 2020-01-07
# NKEBUY on 2020-01-08
# NKEBUY on 2020-01-09
# NKEBUY on 2020-01-10
# NKEBUY on 2020-01-30
# NKEBUY on 2020-01-31
# NKEBUY on 2020-02-27
# NKEBUY on 2020-03-12
# NKEBUY on 2020-03-16
# NKEBUY on 2022-01-20
# NKEBUY on 2022-01-21
# NKEBUY on 2022-03-08
# NKEBUY on 2022-09-30
# NKEBUY on 2023-05-25
# NKEBUY on 2023-05-26
# NKEBUY on 2023-05-30
# NKEBUY on 2023-05-31
# NKEBUY on 2023-06-01
# NKEBUY on 2023-08-23
# NKEBUY on 2023-08-24
# NKEBUY on 2023-09-21
# NKEBUY on 2023-09-22
# NKEBUY on 2023-09-25
# NKEBUY on 2023-09-26
# NKEBUY on 2023-09-27
# NKEBUY on 2023-09-28
# NKEBUY on 2024-06-28
# NKEBUY on 2024-07-01
# NKEBUY on 2024-07-02
# NKEBUY on 2024-07-03
# NKEBUY on 2024-07-05
# NKEBUY on 2024-07-08
# NKEBUY on 2024-07-09
# NKEBUY on 2024-07-10
# NKEBUY on 2024-07-11
# NKEBUY on 2024-07-12
# NKEBUY on 2024-07-15
# NKEBUY on 2025-03-28
# NKEBUY on 2025-03-31
# NKEBUY on 2025-04-03
# NKEBUY on 2025-04-04
# NKEBUY on 2025-04-07
# NKEBUY on 2025-04-08
# NKEBUY on 2020-06-03-RSI = 75.0
# NKEBUY on 2020-08-24-RSI = 75.7
# NKEBUY on 2020-09-01-RSI = 77.0
# NKEBUY on 2020-09-02-RSI = 79.5
# NKEBUY on 2021-06-25-RSI = 82.1
# NKEBUY on 2021-06-28-RSI = 77.2
# NKEBUY on 2021-06-29-RSI = 79.6
# NKEBUY on 2021-06-30-RSI = 76.1
# NKEBUY on 2021-07-01-RSI = 78.5
# NKEBUY on 2021-07-02-RSI = 79.6
# NKEBUY on 2021-07-06-RSI = 79.9
# NKEBUY on 2021-07-07-RSI = 79.9
# NKEBUY on 2021-07-08-RSI = 80.2
# NKEBUY on 2021-07-09-RSI = 80.5
# NKEBUY on 2021-07-12-RSI = 81.1
# NKEBUY on 2021-07-13-RSI = 80.4
# NKEBUY on 2021-07-14-RSI = 80.2
# NKEBUY on 2021-07-15-RSI = 80.3
# NKEBUY on 2021-07-23-RSI = 77.5
# NKEBUY on 2021-07-30-RSI = 75.3
# NKEBUY on 2021-08-02-RSI = 76.8
# NKEBUY on 2021-08-03-RSI = 79.5
# NKEBUY on 2021-08-04-RSI = 80.2
# NKEBUY on 2021-08-05-RSI = 82.0
# NKEBUY on 2021-08-06-RSI = 77.8
# NKEBUY on 2021-11-04-RSI = 76.6
# NKEBUY on 2021-11-05-RSI = 78.3
# NKEBUY on 2023-12-06-RSI = 75.7
# NKEBUY on 2023-12-11-RSI = 76.0
# NKEBUY on 2023-12-12-RSI = 77.4
# NKEBUY on 2023-12-13-RSI = 79.3
# NKEBUY on 2023-12-14-RSI = 78.6
# NKEBUY on 2023-12-15-RSI = 79.3
# NKEBUY on 2023-12-18-RSI = 77.2
# NKEBUY on 2023-12-19-RSI = 79.3
# NKEBUY on 2023-12-21-RSI = 75.2
# NKEBUY on 2024-09-26-RSI = 76.5
# NKEBUY on 2024-09-27-RSI = 76.6
# NKEBUY on 2025-07-02-RSI = 76.6
# NKEBUY on 2025-07-03-RSI = 76.6
# NKEBUY on 2025-07-07-RSI = 76.7
# MultiIndex([( 'Close', 'BABA'),
#             (  'High', 'BABA'),
#             (   'Low', 'BABA'),
#             (  'Open', 'BABA'),
#             ('Volume', 'BABA')],
#            names=['Price', 'Ticker'])
# /tmp/ipython-input-839104772.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df= yf.download(ticket, start="2020-01-01")
# [*********************100%***********************]  1 of 1 completed
# Ticker          BABA
# count   1.490000e+03
# mean    2.052662e+07
# std     1.360494e+07
# min     5.235400e+06
# 25%     1.277898e+07
# 50%     1.721095e+07
# 75%     2.332705e+07
# max     1.598343e+08
# Ticker      BABA
# Date
# 2020-01-02   NaN
# 2020-01-03   NaN
# 2020-01-06   NaN
# 2020-01-07   NaN
# 2020-01-08   NaN
# ...          ...
# 2025-11-28   NaN
# 2025-12-01   NaN
# 2025-12-02   NaN
# 2025-12-03   NaN
# 2025-12-04   NaN
#
# [1490 rows x 1 columns]
# Ticker          BABA
# Date
# 2020-01-02       NaN
# 2020-01-03 -0.457933
# 2020-01-06  0.381312
# 2020-01-07 -0.210130
# 2020-01-08  0.273871
# ...              ...
# 2025-11-28 -0.665060
# 2025-12-01  1.132239
# 2025-12-02 -0.355240
# 2025-12-03 -0.294630
# 2025-12-04 -0.050646
#
# [1490 rows x 1 columns]
# BABABUY on 2020-01-03
# BABABUY on 2020-01-06
# BABABUY on 2020-01-07
# BABABUY on 2020-01-08
# BABABUY on 2020-01-09
# BABABUY on 2020-01-10
# BABABUY on 2020-01-24
# BABABUY on 2020-01-27
# BABABUY on 2020-12-24
# BABABUY on 2020-12-28
# BABABUY on 2021-08-19
# BABABUY on 2021-08-20
# BABABUY on 2021-08-23
# BABABUY on 2021-12-01
# BABABUY on 2021-12-02
# BABABUY on 2021-12-03
# BABABUY on 2022-03-11
# BABABUY on 2022-03-14
# BABABUY on 2022-03-15
# BABABUY on 2022-10-24
# BABABUY on 2023-03-09
# BABABUY on 2023-03-10
# BABABUY on 2023-03-13
# BABABUY on 2023-03-15
# BABABUY on 2023-03-20
# BABABUY on 2025-04-08
# BABABUY on 2020-07-08-RSI = 75.0
# BABABUY on 2020-07-09-RSI = 76.4
# BABABUY on 2020-07-10-RSI = 75.7
# BABABUY on 2020-08-26-RSI = 76.7
# BABABUY on 2023-01-09-RSI = 75.5
# BABABUY on 2023-01-10-RSI = 77.9
# BABABUY on 2023-01-11-RSI = 78.0
# BABABUY on 2023-01-13-RSI = 76.7
# BABABUY on 2024-09-24-RSI = 78.4
# BABABUY on 2024-09-26-RSI = 80.9
# BABABUY on 2024-09-27-RSI = 82.3
# BABABUY on 2024-09-30-RSI = 79.1
# BABABUY on 2024-10-01-RSI = 83.0
# BABABUY on 2024-10-02-RSI = 84.2
# BABABUY on 2024-10-03-RSI = 78.4
# BABABUY on 2024-10-04-RSI = 79.5
# BABABUY on 2024-10-07-RSI = 81.3
# BABABUY on 2025-01-29-RSI = 75.0
# BABABUY on 2025-01-30-RSI = 81.0
# BABABUY on 2025-02-10-RSI = 77.0
# BABABUY on 2025-02-11-RSI = 78.0
# BABABUY on 2025-02-12-RSI = 81.3
# BABABUY on 2025-02-13-RSI = 81.9
# BABABUY on 2025-02-14-RSI = 84.4
# BABABUY on 2025-02-18-RSI = 85.3
# BABABUY on 2025-02-19-RSI = 82.7
# BABABUY on 2025-02-20-RSI = 86.7
# BABABUY on 2025-02-21-RSI = 88.9
# BABABUY on 2025-09-16-RSI = 76.3
# BABABUY on 2025-09-17-RSI = 78.1
# BABABUY on 2025-09-24-RSI = 78.5
# BABABUY on 2025-09-25-RSI = 77.1
# BABABUY on 2025-09-29-RSI = 75.8
# BABABUY on 2025-10-01-RSI = 76.1
# BABABUY on 2025-10-02-RSI = 78.9
# BABABUY on 2025-10-03-RSI = 77.0
# BABABUY on 2025-10-06-RSI = 75.7
# MultiIndex([( 'Close', 'JD'),
#             (  'High', 'JD'),
#             (   'Low', 'JD'),
#             (  'Open', 'JD'),
#             ('Volume', 'JD')],
#            names=['Price', 'Ticker'])
# Ticker            JD
# count   1.490000e+03
# mean    1.256009e+07
# std     7.468043e+06
# min     2.140800e+06
# 25%     7.948625e+06
# 50%     1.063470e+07
# 75%     1.465502e+07
# max     8.606530e+07
# Ticker             JD
# Date
# 2020-01-02  34.236385
# 2020-01-03  34.472313
# 2020-01-06        NaN
# 2020-01-07        NaN
# 2020-01-08        NaN
# ...               ...
# 2025-11-28        NaN
# 2025-12-01        NaN
# 2025-12-02        NaN
# 2025-12-03        NaN
# 2025-12-04        NaN
#
# [1490 rows x 1 columns]
# Ticker            JD
# Date
# 2020-01-02       NaN
# 2020-01-03 -0.253818
# 2020-01-06 -0.424681
# 2020-01-07  0.040164
# 2020-01-08  0.128651
# ...              ...
# 2025-11-28 -0.492992
# 2025-12-01  0.686047
# 2025-12-02 -0.449245
# 2025-12-03 -0.126246
# 2025-12-04  0.234698
#
# [1490 rows x 1 columns]
# JDBUY on 2022-03-11
# JDBUY on 2022-03-14
# JDBUY on 2022-10-14
# JDBUY on 2022-10-24
# JDBUY on 2023-02-24
# JDBUY on 2023-02-27
# JDBUY on 2023-02-28
# JDBUY on 2023-03-10
# JDBUY on 2023-03-13
# JDBUY on 2023-03-15
# JDBUY on 2023-03-17
# JDBUY on 2023-03-20
# JDBUY on 2023-09-28
# JDBUY on 2023-10-20
# JDBUY on 2020-01-03-RSI = 100.0
# JDBUY on 2020-01-06-RSI = 100.0
# JDBUY on 2020-01-07-RSI = 100.0
# JDBUY on 2020-01-08-RSI = 99.4
# JDBUY on 2020-01-09-RSI = 99.5
# JDBUY on 2020-01-10-RSI = 99.5
# JDBUY on 2020-01-13-RSI = 99.6
# JDBUY on 2020-01-14-RSI = 99.2
# JDBUY on 2020-01-15-RSI = 87.7
# JDBUY on 2020-01-16-RSI = 83.2
# JDBUY on 2020-01-17-RSI = 86.0
# JDBUY on 2020-01-21-RSI = 80.7
# JDBUY on 2020-01-22-RSI = 84.0
# JDBUY on 2020-01-23-RSI = 80.8
# JDBUY on 2020-05-18-RSI = 78.6
# JDBUY on 2020-08-21-RSI = 75.8
# JDBUY on 2020-08-24-RSI = 77.2
# JDBUY on 2020-08-25-RSI = 80.2
# JDBUY on 2020-08-26-RSI = 81.5
# JDBUY on 2020-08-27-RSI = 77.3
# JDBUY on 2020-08-28-RSI = 78.0
# JDBUY on 2020-09-01-RSI = 77.5
# JDBUY on 2020-09-02-RSI = 78.3
# JDBUY on 2024-05-03-RSI = 75.3
# JDBUY on 2024-05-17-RSI = 76.1
# JDBUY on 2024-09-24-RSI = 81.0
# JDBUY on 2024-09-25-RSI = 75.9
# JDBUY on 2024-09-26-RSI = 83.6
# JDBUY on 2024-09-27-RSI = 85.6
# JDBUY on 2024-09-30-RSI = 85.7
# JDBUY on 2024-10-01-RSI = 88.2
# JDBUY on 2024-10-02-RSI = 89.5
# JDBUY on 2024-10-03-RSI = 88.4
# JDBUY on 2024-10-04-RSI = 89.9
# JDBUY on 2024-10-07-RSI = 90.0
